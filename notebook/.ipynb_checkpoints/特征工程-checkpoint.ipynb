# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("../dataset/used_car_train_20200313.csv",sep=" ")
test_data = pd.read_csv("../dataset/used_car_testA_20200313.csv",sep=" ")

# %%
print(train_data.columns)
print(test_data.columns)
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'notRepairedDamage', 'regionCode',
#        'seller', 'offerType', 'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3',
#        'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12',
#        'v_13', 'v_14'],
#       dtype='object')
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'notRepairedDamage', 'regionCode',
#        'seller', 'offerType', 'creatDate', 'v_0', 'v_1', 'v_2', 'v_3', 'v_4',
#        'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12', 'v_13',
#        'v_14'],
#       dtype='object')

# %%
train_data = train_data.drop(["seller","offerType","name"],axis=1)
test_data = test_data.drop(["seller","offerType","name"],axis=1)

# %%
train_data.isnull().sum()
# Out:
# SaleID                  0
# regDate                 0
# model                   1
# brand                   0
# bodyType             4506
# fuelType             8680
# gearbox              5981
# power                   0
# kilometer               0
# notRepairedDamage       0
# regionCode              0
# creatDate               0
# price                   0
# v_0                     0
# v_1                     0
# v_2                     0
# v_3                     0
# v_4                     0
# v_5                     0
# v_6                     0
# v_7                     0
# v_8                     0
# v_9                     0
# v_10                    0
# v_11                    0
# v_12                    0
# v_13                    0
# v_14                    0
# dtype: int64

# %%
for i in train_data.columns:
    print(i,train_data[i].unique().size)
# Out:
# SaleID 150000
# regDate 3894
# model 249
# brand 40
# bodyType 9
# fuelType 8
# gearbox 3
# power 566
# kilometer 13
# notRepairedDamage 3
# regionCode 7905
# creatDate 96
# price 3763
# v_0 143997
# v_1 143998
# v_2 143997
# v_3 143998
# v_4 143998
# v_5 139624
# v_6 109766
# v_7 138709
# v_8 142451
# v_9 140617
# v_10 143997
# v_11 143997
# v_12 143997
# v_13 143998
# v_14 143998

# %%
#power
def outliers_proc(data, col_name, scale=3):
    """
        用于截尾异常值， 默认用box_plot(scale=3)进行清洗
        param:
            data：接收pandas数据格式
            col_name: pandas列名
            scale: 尺度
    """
    data_col = data[col_name]
    Q1 = data_col.quantile(0.25) # 0.25分位数
    Q3 = data_col.quantile(0.75)  # 0,75分位数
    IQR = Q3 - Q1

    data_col[data_col < Q1 - (scale * IQR)] = Q1 - (scale * IQR)
    data_col[data_col > Q3 + (scale * IQR)] = Q3 + (scale * IQR)

    return data[col_name]

train_data["power"] = outliers_proc(train_data,'power')
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
'''
bodyType             4506
fuelType             8680
gearbox              5981
'''
train_data["bodyType"] = train_data.bodyType.fillna(train_data.bodyType.mode())
train_data["fuelType"] = train_data.fuelType.fillna(train_data.fuelType.mode())
trian_data["gearbox"] = train_data.gearbox.fillna(train_data.gearbox.mode())

test_data["bodyType"] = test_data.bodyType.fillna(test_data.bodyType.mode())
test_data["fuelType"] = test_data.fuelType.fillna(test_data.fuelType.mode())
test_data["gearbox"] = test_data.gearbox.fillna(test_data.gearbox.mode())

# %%
train_data["train"] = 1
test_data["train"] = 0
data = pd.concat([train_data,test_data],ignore_index=True)

# %%
data
# Out:
#         SaleID   regDate  model  brand  bodyType  fuelType  gearbox  power  \
# 0            0  20040402   30.0      6       1.0       0.0      0.0     60
# 1            1  20030301   40.0      1       2.0       0.0      0.0      0
# 2            2  20040403  115.0     15       1.0       0.0      0.0    163
# 3            3  19960908  109.0     10       0.0       0.0      1.0    193
# 4            4  20120103  110.0      5       1.0       0.0      0.0     68
# ...        ...       ...    ...    ...       ...       ...      ...    ...
# 199995  199995  19960503    4.0      4       4.0       0.0      0.0    116
# 199996  199996  19991011    0.0      0       0.0       0.0      0.0     75
# 199997  199997  20040412   49.0      1       0.0       1.0      1.0    224
# 199998  199998  20020008   27.0      1       0.0       0.0      1.0    334
# 199999  199999  20041109  166.0      6       1.0       NaN      1.0     68
#
# ...

# %%
data['used_time'] = (pd.to_datetime(data['creatDate'], format='%Y%m%d', errors='coerce') - 
                            pd.to_datetime(data['regDate'], format='%Y%m%d', errors='coerce')).dt.days

# %%
data['used_time'].isnull().sum()
# Out:
# 15101

# %%
data = data.drop(["SaleID","regDate","creatDate"],axis=1)

# %%
data["notRepairedDamage"].replace("-",np.nan,inplace=True)

# %%
data["notRepairedDamage"] = data["notRepairedDamage"].astype("float")

# %%
data["notRepairedDamage"] = data["notRepairedDamage"].fillna(-1)

# %%
train_data = data[data["train"]==1]
test_data = data[data["train"]==0]

# %%
train_data = train_data.drop(["train","price"],axis=1)
test_data = test_data.drop(["train","price"],axis=1)

# %%
X_data = pd.get_dummies(train_data)
X_test = pd.get_dummies(test_data)

# %%
train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-3b59e1edcf43> in <module>
# ----> 1 y = train_data["price"]
#
# ...

# %%
train_x = X_data[:int(len(X_data)*0.8)]
valid_x = X_data[int(len(X_data)*0.8):]
train_y = y[:int(len(X_data)*0.8)]
valid_y = y[int(len(X_data)*0.8):]
